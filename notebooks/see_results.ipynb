# %%
import pandas as pd

# %%
# q1 = pd.read_parquet("../output/q1_results.parquet")
# q2 = pd.read_parquet("../output/q2_results.parquet")
# q3 = pd.read_parquet("../output/q3_results.parquet")

# %%
# print(q1.head())
# print(q2.head())
# print(q3.head())
# Out:
#     football_season     league_name  total_xGoals_last20  league_rank
# 0              2014         La Liga           316.944819            1
# 1              2014  Premier League           284.520503            2
# 2              2014         Serie A           273.584495            3
# 3              2014         Ligue 1           260.422988            4
# 4              2014      Bundesliga           233.272203            5
# 5              2015         La Liga           322.579867            1
# 6              2015         Serie A           283.962337            2
# 7              2015         Ligue 1           277.008328            3
# 8              2015  Premier League           275.621105            4
# 9              2015      Bundesliga           265.073611            5
# 10             2016         Serie A           319.448805            1
# 11             2016         La Liga           307.722604            2
# ...
