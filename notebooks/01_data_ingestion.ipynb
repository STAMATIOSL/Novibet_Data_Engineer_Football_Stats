# %%
import pandas as pd
from pathlib import Path
BASE = Path("../")
RAW = BASE/"data"/"raw"
PROC = BASE/"data"/"processed"

# %%
for f in RAW.glob("*.csv"):
    print(f.name)
    display(pd.read_csv(f, nrows=5))

# %%
# !python ../scripts/etl_to_parquet.py
